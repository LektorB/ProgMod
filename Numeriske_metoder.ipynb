# %% [markdown]
# ## Likninger og liknigsett

# %% [markdown]
# ## Numerisk derivasjon

# %% [markdown]
# Et lite utklipp fra R1-boken din:
# #### Newtons kvotient
# ![image.png](attachment:d8ef3660-2ec6-40aa-abf4-833741fe09e9.png)
# ![image.png](attachment:2304f6c2-f4b2-4452-a71f-be3c292a9983.png)

# %% [markdown]
# ![image.png](attachment:00db4e2c-5bd6-4a59-aed9-e0ba77bbd92d.png)

# %% [markdown]
# ### Newtons symetriske kvotient:
# ![image.png](attachment:f4e6f7ce-a918-45f2-8d38-6ce9811e7b5d.png)
# **Oppgave gjenta "utforsk" fra i sted, men med newtons symetriske kvotient som tilnærming til den deriverte**

# %% [markdown]
# #### Innebygget funksjon
# Scipy har en deriverings funksjon som bruker newtons symetrisk kvotient:
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.misc.derivative.html

# %%
from scipy.misc import derivative
def f(x):
    return x**3 + x**2
derivative(f, 1.0, dx=1e-6)

# %% [markdown]
# **Utfordring**
#
# Bruk at den dobbeltderiverte er den deriverte av den deriverte og vis at den dobbelt deriverte kan estimeres som:
# $$ f''(x) = \frac{f(a+\Delta x)-2f(a)+f(a-\Delta x)}{\Delta x^2}$$
# med symetrisk skjema.
#
# Lag et program som regner ut den dobbeltderiverte i et punkt og sammenlign resultatet om du bruker scipy sin funksjon med n=2
#
# derivative(f, 1.0, dx=1e-6, n=2)

# %% [markdown]
# #### Trenger du enda en utfordring? - numerisk funksjonsanalyse
# Lag et program som bruker f.eks newtons metode til å bestemme nullpunktet til den (numeriske) deriverte til en vilkårlig funksjon. Bruk så dobbeltderiverttesten (igjen numerisk) til å avgjøre om verdien du har funnet gir et topp eller bunnpunkt til den opprinnelige funksjonen. (Om testen er nært null bør du advare om at punktet kan være et terassepunkt)
# **PS:** kan være lurt å tegne grafen samtidig

# %% [markdown]
# ## Numerisk derivasjon på datasett
# #### med løkke:

# %% [markdown]
# #### med slicing:

# %% [markdown]
# #### med np.diff()

# %% [markdown]
# På blokkdagen skal vi jobbe med derivering av datasett
# https://github.com/LektorB/ProgMod/blob/main/BONUS%20-%20Derivere%20bilder.ipynb

# %% [markdown]
# ## Numerisk integrasjon
